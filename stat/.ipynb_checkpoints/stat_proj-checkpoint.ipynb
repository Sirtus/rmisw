# %% [markdown]
# # Load dataset into dataframe

# %%
preprocess <- function(data) {
  # Remove columns with excessive missing values
  data <- data[, colSums(is.na(data)) < 0.4 * nrow(data)]
  
  # Impute missing values for numerical variables
  num_vars <- sapply(data, is.numeric)
  data[num_vars] <- lapply(data[num_vars], function(x) ifelse(is.na(x), mean(x, na.rm = TRUE), x))
  
  # Impute missing values for categorical variables
  cat_vars <- sapply(data, is.factor)
  data[cat_vars] <- lapply(data[cat_vars], function(x) ifelse(is.na(x), "NA", x))
  
  # Convert categorical variables to factors
  data[cat_vars] <- lapply(data[cat_vars], as.factor)
  
  # Normalize numerical variables
  data[num_vars] <- lapply(data[num_vars], function(x) (x - mean(x)) / sd(x))
                           
  return(data)
}

# function that removes columns with only one unqie value 
remove_unique <- function(data) {
  data <- data[, sapply(data, function(x) length(unique(x))) > 1]
  return(data)
}

# %%
library(leaps)

# %%
path <- "./AmesHousing.csv"
data <- read.csv(path)
column_list <- c('Fireplaces', 'Overall.Cond', 'MS.SubClass', "Open.Porch.SF", "Wood.Deck.SF", 'Land.Slope', 'Lot.Area', "Lot.Frontage", "Year.Built", "Roof.Style", "Utilities", "Street", "Full.Bath", "Half.Bath", "Bedroom.AbvGr", "Kitchen.AbvGr", "Garage.Area", "Paved.Drive", "Sale.Condition", "SalePrice", "Yr.Sold", "Garage.Cars", "Heating", "Electrical", "Exterior.1st", "Exterior.2nd", "Overall.Qual", "Central.Air")
data <- data[, column_list]
data <- preprocess(data)
data <- remove_unique(data)
data <- na.omit(data)
data_numeric <- data[, sapply(data, is.numeric)]
dim(data_numeric)
# Out:
# [1] 2930   17

# %%
names(data)
# Out:
#  [1] "Fireplaces"     "Overall.Cond"   "MS.SubClass"    "Open.Porch.SF"
#  [5] "Wood.Deck.SF"   "Land.Slope"     "Lot.Area"       "Lot.Frontage"
#  [9] "Year.Built"     "Roof.Style"     "Utilities"      "Street"
# [13] "Full.Bath"      "Half.Bath"      "Bedroom.AbvGr"  "Kitchen.AbvGr"
# [17] "Garage.Area"    "Paved.Drive"    "Sale.Condition" "SalePrice"
# [21] "Yr.Sold"        "Garage.Cars"    "Heating"        "Electrical"
# [25] "Exterior.1st"   "Exterior.2nd"   "Overall.Qual"   "Central.Air"

# %%
head(data)
# Out:
#   Fireplaces Overall.Cond MS.SubClass Open.Porch.SF Wood.Deck.SF Land.Slope
# 1  2.1618110 -0.5066319   -0.8768552   0.2143720     0.9199643   Gtl
# 2 -0.9249854  0.3930236   -0.8768552  -0.7043724     0.3659983   Gtl
# 3 -0.9249854  0.3930236   -0.8768552  -0.1709079     2.3681895   Gtl
# 4  2.1618110 -0.5066319   -0.8768552  -0.7043724    -0.7419335   Gtl
# 5  0.6184128 -0.5066319    0.0612746  -0.2005448     0.9357919   Gtl
# 6  0.6184128  0.3930236    0.0612746  -0.1709079     2.1070341   Gtl
#   Lot.Area    Lot.Frontage Year.Built Roof.Style ⋯ Sale.Condition SalePrice
# 1  2.74391236 3.3663359    -0.3754729 Hip        ⋯ Normal          0.4281557
# 2  0.18706533 0.5053771    -0.3424100 Gable      ⋯ Normal         -0.9487946
# 3  0.52272448 0.5522781    -0.4415988 Hip        ⋯ Normal         -0.1101067
# 4  0.12843602 1.1150897    -0.1109695 Hip        ⋯ Normal          0.7911698
# 5  0.46726775 0.2239713     0.8478552 Gable      ⋯ Normal          0.1139607
# 6 -0.02156364 0.4115752     0.8809181 Gable      ⋯ Normal          0.1840599
#   Yr.Sold  Garage.Cars Heating Electrical Exterior.1st Exterior.2nd
# 1 1.678213  0.3066468  GasA    SBrkr      BrkFace      Plywood
# 2 1.678213 -1.0083874  GasA    SBrkr      VinylSd      VinylSd
# 3 1.678213 -1.0083874  GasA    SBrkr      Wd Sdng      Wd Sdng
# 4 1.678213  0.3066468  GasA    SBrkr      BrkFace      BrkFace
# 5 1.678213  0.3066468  GasA    SBrkr      VinylSd      VinylSd
# 6 1.678213  0.3066468  GasA    SBrkr      VinylSd      VinylSd
#   Overall.Qual Central.Air
# 1 -0.06724223  Y
# 2 -0.77594635  Y
# 3 -0.06724223  Y
# 4  0.64146189  Y
# 5 -0.77594635  Y
# 6 -0.06724223  Y

# %% [markdown]
# # Linear Regression

# %% [markdown]
# ## SalePrice ~ Overall.Qual

# %%
fit_simple <- lm(data$SalePrice ~ data$Overall.Qual)
coef(fit_simple)
# Out:
#       (Intercept) data$Overall.Qual
#     -1.606469e-16      7.992618e-01

# %%
summaryList <- summary(fit_simple)
summaryList$sigma
summaryList$r.squared
summaryList$fstatistic
# Out:
# [1] 0.6010856
# [1] 0.6388194
#    value    numdf    dendf
# 5178.748    1.000 2928.000

# %%
summary(fit_simple)
confint(fit_simple)
# Out:
# Call:
# lm(formula = data$SalePrice ~ data$Overall.Qual)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -2.4723 -0.3662 -0.0286  0.2711  4.9757
#
# Coefficients:
#                     Estimate Std. Error t value Pr(>|t|)
# (Intercept)       -1.606e-16  1.110e-02    0.00        1
# data$Overall.Qual  7.993e-01  1.111e-02   71.96   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.6011 on 2928 degrees of freedom
# Multiple R-squared:  0.6388,	Adjusted R-squared:  0.6387
# F-statistic:  5179 on 1 and 2928 DF,  p-value: < 2.2e-16
#                   2.5 %      97.5 %
# (Intercept)       -0.0217736 0.0217736
# data$Overall.Qual  0.7774845 0.8210391

# %% [markdown]
# Model jest statystycznie istotny. Overall.Qual ma wpływ na cenę sprzedaży domów.

# %% [markdown]
# ### Make predictions

# %%
predict(fit_simple, newdata=data.frame(OverallQual = c(5, 6, 7)), interval = "confidence")
# Out:
# Warning message:
# “'newdata' miała 3 wiersze ale znalezione zmienne mają 2930 wierszy”
#      fit         lwr         upr
# 1    -0.05374415 -0.07556693 -0.03192136
# 2    -0.62018428 -0.64774571 -0.59262284
# 3    -0.05374415 -0.07556693 -0.03192136
# 4     0.51269598  0.48682647  0.53856549
# 5    -0.62018428 -0.64774571 -0.59262284
# 6    -0.05374415 -0.07556693 -0.03192136
# 7     1.07913611  1.04254888  1.11572334
# 8     1.07913611  1.04254888  1.11572334
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”

# %% [markdown]
# ## Linear Regression for two atributes

# %%
fit_og <- lm(data$SalePrice ~ data$Overall.Qual + data$Garage.Cars)
summary(fit_og)
# Out:
# Call:
# lm(formula = data$SalePrice ~ data$Overall.Qual + data$Garage.Cars)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -2.1639 -0.3480 -0.0390  0.2489  4.9856
#
# Coefficients:
#                     Estimate Std. Error t value Pr(>|t|)
# (Intercept)       -3.962e-16  1.040e-02    0.00        1
# data$Overall.Qual  6.414e-01  1.300e-02   49.35   <2e-16 ***
# data$Garage.Cars   2.634e-01  1.300e-02   20.26   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.563 on 2927 degrees of freedom
# Multiple R-squared:  0.6833,	Adjusted R-squared:  0.683
# F-statistic:  3157 on 2 and 2927 DF,  p-value: < 2.2e-16

# %% [markdown]
# ## Linear Regression for all atributes

# %%
fit_all <- lm(SalePrice ~ ., data = data)
summary(fit_all)
# Out:
# Call:
# lm(formula = SalePrice ~ ., data = data)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -4.4525 -0.2659 -0.0286  0.2086  4.6902
#
# Coefficients: (1 not defined because of singularities)
#                        Estimate Std. Error t value Pr(>|t|)
# (Intercept)           -0.141533   0.696029  -0.203  0.83888
# Fireplaces             0.123684   0.010354  11.946  < 2e-16 ***
# Overall.Cond           0.051770   0.010427   4.965 7.28e-07 ***
# MS.SubClass           -0.061701   0.010759  -5.735 1.08e-08 ***
# Open.Porch.SF          0.026822   0.009479   2.830  0.00469 **
# Wood.Deck.SF           0.068817   0.009374   7.341 2.75e-13 ***
# Land.SlopeMod          0.226767   0.044037   5.149 2.79e-07 ***
# Land.SlopeSev         -0.065281   0.144590  -0.451  0.65167
# Lot.Area               0.088452   0.011411   7.751 1.25e-14 ***
# Lot.Frontage           0.053497   0.010976   4.874 1.15e-06 ***
# Year.Built             0.089116   0.017610   5.060 4.45e-07 ***
# Roof.StyleGable       -0.024080   0.116265  -0.207  0.83594
# Roof.StyleGambrel      0.061872   0.154902   0.399  0.68961
# Roof.StyleHip          0.184663   0.117900   1.566  0.11740
# Roof.StyleMansard     -0.176544   0.187275  -0.943  0.34592
# Roof.StyleShed         0.047971   0.239383   0.200  0.84119
# UtilitiesNoSeWa       -0.316079   0.469900  -0.673  0.50122
# UtilitiesNoSewr       -0.296788   0.341872  -0.868  0.38540
# StreetPave             0.449178   0.144184   3.115  0.00186 **
# Full.Bath              0.112058   0.012823   8.739  < 2e-16 ***
# Half.Bath              0.064379   0.010127   6.357 2.39e-10 ***
# Bedroom.AbvGr          0.027703   0.010893   2.543  0.01103 *
# Kitchen.AbvGr         -0.008558   0.010463  -0.818  0.41348
# Garage.Area            0.146425   0.019939   7.344 2.70e-13 ***
# Paved.DriveP          -0.125613   0.069015  -1.820  0.06885 .
# Paved.DriveY          -0.089479   0.040357  -2.217  0.02669 *
# Sale.ConditionAdjLand  0.102833   0.147435   0.697  0.48556
# Sale.ConditionAlloca   0.212294   0.107054   1.983  0.04746 *
# Sale.ConditionFamily  -0.040868   0.077452  -0.528  0.59778
# Sale.ConditionNormal   0.073993   0.036424   2.031  0.04231 *
# Sale.ConditionPartial  0.288389   0.049740   5.798 7.45e-09 ***
# Yr.Sold               -0.005929   0.008858  -0.669  0.50332
# Garage.Cars            0.022816   0.020794   1.097  0.27264
DF,  p-value: < 2.2e-16

# %% [markdown]
# ## Linear regression without one atribute

# %%
fit_ay <- lm(SalePrice ~ . - Sale.Condition, data = data)
summary(fit_ay)
# Out:
# Call:
# lm(formula = SalePrice ~ . - Sale.Condition, data = data)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -4.3404 -0.2728 -0.0269  0.2088  4.6563
#
# Coefficients: (1 not defined because of singularities)
#                       Estimate Std. Error t value Pr(>|t|)
# (Intercept)         -0.0010249  0.6986353  -0.001  0.99883
# Fireplaces           0.1212664  0.0104060  11.653  < 2e-16 ***
# Overall.Cond         0.0533683  0.0104308   5.116 3.32e-07 ***
# MS.SubClass         -0.0660429  0.0108114  -6.109 1.14e-09 ***
# Open.Porch.SF        0.0281327  0.0095338   2.951  0.00319 **
# Wood.Deck.SF         0.0642476  0.0094115   6.827 1.06e-11 ***
# Land.SlopeMod        0.2241027  0.0442870   5.060 4.45e-07 ***
# Land.SlopeSev       -0.0722823  0.1453242  -0.497  0.61895
# Lot.Area             0.0891776  0.0114909   7.761 1.17e-14 ***
# Lot.Frontage         0.0547370  0.0110290   4.963 7.35e-07 ***
# Year.Built           0.1037648  0.0175940   5.898 4.12e-09 ***
# Roof.StyleGable     -0.0419635  0.1157917  -0.362  0.71708
# Roof.StyleGambrel    0.0656895  0.1554920   0.422  0.67272
# Roof.StyleHip        0.1740267  0.1175083   1.481  0.13872
# Roof.StyleMansard   -0.2091114  0.1875172  -1.115  0.26488
# Roof.StyleShed       0.0006769  0.2405306   0.003  0.99775
# UtilitiesNoSeWa     -0.3765130  0.4720802  -0.798  0.42519
# UtilitiesNoSewr     -0.2939852  0.3440460  -0.854  0.39290
# StreetPave           0.4038682  0.1425766   2.833  0.00465 **
# Full.Bath            0.1154039  0.0128919   8.952  < 2e-16 ***
# Half.Bath            0.0647940  0.0102002   6.352 2.46e-10 ***
# Bedroom.AbvGr        0.0221408  0.0109264   2.026  0.04282 *
# Kitchen.AbvGr       -0.0042451  0.0103396  -0.411  0.68142
# Garage.Area          0.1517564  0.0200287   7.577 4.75e-14 ***
# Paved.DriveP        -0.1232633  0.0694609  -1.775  0.07608 .
# Paved.DriveY        -0.1018928  0.0405873  -2.510  0.01211 *
# Yr.Sold             -0.0136897  0.0087905  -1.557  0.11950
# Garage.Cars          0.0219665  0.0208836   1.052  0.29296
# HeatingGasA          0.0626882  0.4729831   0.133  0.89457
# HeatingGasW          0.0096629  0.4819977   0.020  0.98401
# HeatingGrav          0.0558890  0.4979744   0.112  0.91065
# HeatingOthW         -0.3853951  0.5807697  -0.664  0.50700
# HeatingWall          0.0493356  0.5171168   0.095  0.92400
# ElectricalFuseA     -0.1553530  0.4719569  -0.329  0.74205
# ElectricalFuseF     -0.2532134  0.4759795  -0.532  0.59478
# ElectricalFuseP     -0.1467065  0.5006217  -0.293  0.76951
# ElectricalMix       -0.5416470  0.6677857  -0.811  0.41737
# ElectricalSBrkr     -0.1828902  0.4702660  -0.389  0.69737
# Exterior.1stAsphShn  0.1055963  0.5058831   0.209  0.83467
# Exterior.1stBrkComm  0.3230781  0.2572638   1.256  0.20928
# Exterior.1stBrkFace  0.2348227  0.1575514   1.490  0.13622
# Exterior.1stCBlock   0.3129607  0.3966062   0.789  0.43012
# Exterior.1stCemntBd  0.1695208  0.2630235   0.645  0.51930
# Exterior.1stHdBoard -0.1261553  0.1534128  -0.822  0.41096
# Exterior.1stImStucc -0.5221956  0.5075507  -1.029  0.30364
# Exterior.1stMetalSd -0.0649905  0.1750150  -0.371  0.71041
# Exterior.1stPlywood -0.0707220  0.1495809  -0.473  0.63639
# Exterior.1stPreCast  1.4947734  0.4917950   3.039  0.00239 **
# Exterior.1stStone    0.4335094  0.3810425   1.138  0.25534
# Exterior.1stStucco  -0.0112328  0.1755334  -0.064  0.94898
# Exterior.1stVinylSd  0.0628435  0.1642393   0.383  0.70202
# Exterior.1stWd Sdng -0.0194032  0.1486106  -0.131  0.89613
# Exterior.1stWdShing -0.0365984  0.1624283  -0.225  0.82175
# Exterior.2ndAsphShn  0.0333559  0.3803654   0.088  0.93013
# Exterior.2ndBrk Cmn -0.2686280  0.1903831  -1.411  0.15836
# Exterior.2ndBrkFace -0.2511175  0.1774494  -1.415  0.15713
# Exterior.2ndCBlock   0.2381290  0.3402626   0.700  0.48408
# Exterior.2ndCmentBd  0.0689990  0.2690501   0.256  0.79762
# Exterior.2ndHdBoard -0.0671950  0.1616932  -0.416  0.67775
# Exterior.2ndImStucc  0.3795470  0.1986175   1.911  0.05611 .
# Exterior.2ndMetalSd  0.0480325  0.1822494   0.264  0.79214
# Exterior.2ndOther    0.4320249  0.5001218   0.864  0.38775
# Exterior.2ndPlywood -0.1475371  0.1549098  -0.952  0.34097
# Exterior.2ndPreCast         NA         NA      NA       NA
# Exterior.2ndStone   -0.0756674  0.2718626  -0.278  0.78078
# Exterior.2ndStucco  -0.2068195  0.1802287  -1.148  0.25125
# Exterior.2ndVinylSd -0.1426902  0.1709020  -0.835  0.40383
# Exterior.2ndWd Sdng -0.1190087  0.1570967  -0.758  0.44878
# Exterior.2ndWd Shng -0.0787041  0.1646800  -0.478  0.63274
# Overall.Qual         0.4586237  0.0142604  32.161  < 2e-16 ***
# Central.AirY        -0.1137878  0.0454240  -2.505  0.01230 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.4692 on 2860 degrees of freedom
# Multiple R-squared:  0.785,	Adjusted R-squared:  0.7798
# F-statistic: 151.4 on 69 and 2860 DF,  p-value: < 2.2e-16

# %% [markdown]
# ### Zbiór ufności dla dwóch współczynników

# %%
library(ellipse)
plot(ellipse(fit_all, which = -1), type = "l")
la_coefs <- coef(fit_all)
points(la_coefs[2], la_coefs[3])
# Out:
# Dołączanie pakietu: ‘ellipse’
#
#
# Następujący obiekt został zakryty z ‘package:graphics’:
#
#     pairs
# plot without title

# %% [markdown]
# # Nonlinear predictor transformations

# %%
fit_nonlinear <- lm(data$SalePrice ~ data$Overall.Qual + I(data$Overall.Qual ^ 2))
summary(fit_nonlinear)
# Out:
# Call:
# lm(formula = data$SalePrice ~ data$Overall.Qual + I(data$Overall.Qual^2))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -3.4776 -0.3098 -0.0143  0.2569  3.9705
#
# Coefficients:
#                         Estimate Std. Error t value Pr(>|t|)
# (Intercept)            -0.163863   0.012528  -13.08   <2e-16 ***
# data$Overall.Qual       0.768035   0.010335   74.32   <2e-16 ***
# I(data$Overall.Qual^2)  0.163919   0.007219   22.71   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.5543 on 2927 degrees of freedom
# Multiple R-squared:  0.6929,	Adjusted R-squared:  0.6927
# F-statistic:  3302 on 2 and 2927 DF,  p-value: < 2.2e-16

# %%
anova(fit_simple, fit_nonlinear)
# Out:
#   Res.Df RSS       Df Sum of Sq F        Pr(>F)
# 1 2928   1057.8979 NA       NA        NA            NA
# 2 2927    899.4515  1 158.4464  515.6173 2.838619e-105

# %% [markdown]
# ## Higher degree polynomial regression

# %%
fit_l7 <- lm(data$SalePrice ~ poly(data$Overall.Qual, 7))
summary(fit_l7)
# Out:
# Call:
# lm(formula = data$SalePrice ~ poly(data$Overall.Qual, 7))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -3.6357 -0.2999 -0.0359  0.2437  3.8124
#
# Coefficients:
#                               Estimate Std. Error t value Pr(>|t|)
# (Intercept)                  1.127e-16  1.009e-02   0.000    1.000
# poly(data$Overall.Qual, 7)1  4.326e+01  5.464e-01  79.163  < 2e-16 ***
# poly(data$Overall.Qual, 7)2  1.259e+01  5.464e-01  23.036  < 2e-16 ***
# poly(data$Overall.Qual, 7)3  4.508e+00  5.464e-01   8.250 2.37e-16 ***
# poly(data$Overall.Qual, 7)4 -7.314e-01  5.464e-01  -1.339    0.181
# poly(data$Overall.Qual, 7)5 -2.335e+00  5.464e-01  -4.272 2.00e-05 ***
# poly(data$Overall.Qual, 7)6 -7.877e-01  5.464e-01  -1.442    0.150
# poly(data$Overall.Qual, 7)7 -2.950e-01  5.464e-01  -0.540    0.589
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.5464 on 2922 degrees of freedom
# Multiple R-squared:  0.7021,	Adjusted R-squared:  0.7014
# F-statistic:   984 on 7 and 2922 DF,  p-value: < 2.2e-16

# %% [markdown]
# ## Logarithmic transformation of the predictor

# %%
summary(lm(data$SalePrice ~ log(data$Overall.Qual)))
# Out:
# Warning message in log(data$Overall.Qual):
# “wyprodukowano wartości NaN”
# Call:
# lm(formula = data$SalePrice ~ log(data$Overall.Qual))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -2.7970 -0.4511 -0.0852  0.3814  4.6511
#
# Coefficients:
#                        Estimate Std. Error t value Pr(>|t|)
# (Intercept)             0.93324    0.02336   39.95   <2e-16 ***
# log(data$Overall.Qual)  1.57510    0.04997   31.52   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.7669 on 1088 degrees of freedom
#   (1840 obserwacji zostało skasowanych z uwagi na braki w nich zawarte)
# Multiple R-squared:  0.4773,	Adjusted R-squared:  0.4768
# F-statistic: 993.5 on 1 and 1088 DF,  p-value: < 2.2e-16

# %% [markdown]
# # Quality predictors

# %%
sales_all_fit <- lm(SalePrice ~ . , data = data)
summary(sales_all_fit)
# Out:
# Call:
# lm(formula = SalePrice ~ ., data = data)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -4.4525 -0.2659 -0.0286  0.2086  4.6902
#
# Coefficients: (1 not defined because of singularities)
#                        Estimate Std. Error t value Pr(>|t|)
# (Intercept)           
# Exterior.1stPreCast    1.494633   0.488999   3.057  0.00226 **
# Exterior.1stStone      0.553471   0.380801   1.453  0.14621
# Exterior.1stStucco    -0.008542   0.176112  -0.049  0.96132
# Exterior.1stVinylSd    0.064187   0.165671   0.387  0.69846
# Exterior.1stWd Sdng   -0.024786   0.149425  -0.166  0.86826
# Exterior.1stWdShing   -0.049142   0.163141  -0.301  0.76327
# Exterior.2ndAsphShn    0.041021   0.377916   0.109  0.91357
# Exterior.2ndBrk Cmn   -0.274762   0.189671  -1.449  0.14755
# Exterior.2ndBrkFace   -0.229983   0.176846  -1.300  0.19354
# Exterior.2ndCBlock     0.259536   0.338149   0.768  0.44284
# Exterior.2ndCmentBd    0.056326   0.267206   0.211  0.83306
# Exterior.2ndHdBoard   -0.060792   0.161296  -0.377  0.70628
# Exterior.2ndImStucc    0.420112   0.197865   2.123  0.03382 *
# Exterior.2ndMetalSd    0.061480   0.181551   0.339  0.73491
# Exterior.2ndOther      0.270984   0.497471   0.545  0.58599
# Exterior.2ndPlywood   -0.139929   0.154738  -0.904  0.36592
# Exterior.2ndPreCast          NA         NA      NA       NA
# Exterior.2ndStone     -0.102592   0.270742  -0.379  0.70477
# Exterior.2ndStucco    -0.217872   0.179740  -1.212  0.22555
# Exterior.2ndVinylSd   -0.150728   0.170605  -0.883  0.37704
# Exterior.2ndWd Sdng   -0.112028   0.156436  -0.716  0.47397
# Exterior.2ndWd Shng   -0.077636   0.164158  -0.473  0.63630
# Overall.Qual           0.449072   0.014250  31.515  < 2e-16 ***
# Central.AirY          -0.112097   0.045280  -2.476  0.01336 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.4658 on 2855 degrees of freedom
# Multiple R-squared:  0.7885,	Adjusted R-squared:  0.783
# F-statistic: 143.8 on 74 and 2855 DF,  p-value: < 2.2e-16

# %%
contrasts(factor(data$Roof.Style))
# Out:
#         Gable Gambrel Hip Mansard Shed
# Flat    0     0       0   0       0
# Gable   1     0       0   0       0
# Gambrel 0     1       0   0       0
# Hip     0     0       1   0       0
# Mansard 0     0       0   1       0
# Shed    0     0       0   0       1

# %% [markdown]
# # Logistic Regresion

# %%
# Convert column to binary 
data$Central.AirT <- ifelse(data$Central.Air == "Y", 1, 0)

# %%
dir_logistic <- list()
dir_logistic$fit <-  glm(Central.AirT ~ Overall.Qual, data=data, family=binomial)
summary(dir_logistic$fit)
# Out:
# Call:
# glm(formula = Central.AirT ~ Overall.Qual, family = binomial,
#     data = data)
#
# Coefficients:
#              Estimate Std. Error z value Pr(>|z|)
# (Intercept)    3.3969     0.1219   27.87   <2e-16 ***
# Overall.Qual   1.4664     0.1048   13.99   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 1438.8  on 2929  degrees of freedom
# Residual deviance: 1164.7  on 2928  degrees of freedom
# AIC: 1168.7
#
# Number of Fisher Scoring iterations: 6

# %% [markdown]
# ## Prediction

# %%
dir_logistic$probs <- predict(dir_logistic$fit, type = "response")
head(dir_logistic$probs)
length(dir_logistic$probs)
# Out:
#         1         2         3         4         5         6
# 0.9643718 0.9054297 0.9643718 0.9871009 0.9054297 0.9643718
# [1] 2930

# %%
dir_logistic$predicted <- ifelse(dir_logistic$probs > 0.5, "Y", "N")

# %%
dir_logistic$cm <- table(dir_logistic$predicted, df$Central.Air)
dir_logistic$cm
# Out:
#
#        N    Y
#   N   14    3
#   Y  182 2731

# %% [markdown]
# ## Proporcja błędów

# %%
mean(dir_logistic$predicted != df$Central.Air)
# Out:
# [1] 0.06313993

# %% [markdown]
# ## Test and training set

# %%
train <- data$Year.Built > 0.3
df_test <- data[!train,]
Central.AirT_test <- data$Central.AirT[!train]

# %%
library(caret)
set.seed(123)  
train <- createDataPartition(data$Central.AirT, p = 0.7, list = FALSE)
df_test <- data[-train, ]
Central.AirT_test <- data$Central.AirT[-train]

# %%
dir_log_te <- list()
dir_log_te$fit <-glm(data$Central.AirT ~ data$Overall.Qual, data=data, family=binomial, subset = train)  
summary(dir_log_te$fit)
# Out:
# Call:
# glm(formula = data$Central.AirT ~ data$Overall.Qual, family = binomial,
#     data = data, subset = train)
#
# Coefficients:
#                   Estimate Std. Error z value Pr(>|z|)
# (Intercept)          6.597      1.005   6.564 5.23e-11 ***
# data$Overall.Qual    1.425      1.336   1.067    0.286
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 16.196  on 1209  degrees of freedom
# Residual deviance: 15.005  on 1208  degrees of freedom
# AIC: 19.005
#
# Number of Fisher Scoring iterations: 10

# %%
dir_log_t$probs <- predict(dir_log_t$fit, df_test, type = "response")
dir_log_t$predicted <- ifelse(dir_log_t$probs > 0.5, 1, 0)
table(dir_log_t$predicted, Central.AirT_test)
# Out:
# Warning message:
# “'newdata' miała 1720 wierszy ale znalezione zmienne mają 2930 wierszy”
# Error in table(dir_log_te$predicted, Central.AirT_test): wszystkie argumenty muszą mieć tę samą długość
# Traceback:
#
# 1. table(dir_log_te$predicted, Central.AirT_test)
# 2. stop("all arguments must have the same length")

# %%
length(Central.AirT_test)
# Out:
# [1] 879

# %%
dim(df_test)
# Out:
# [1] 879  29

# %%
length(dir_log_t$probs)
# Out:
# [1] 2930

# %% [markdown]
# # Regularyzacja

# %% [markdown]
# # Selekcja cech

# %% [markdown]
# ## Preprocessing

# %%
preprocess <- function(data) {
  # Remove columns with excessive missing values
  data <- data[, colSums(is.na(data)) < 0.4 * nrow(data)]
  
  # Impute missing values for numerical variables
  num_vars <- sapply(data, is.numeric)
  data[num_vars] <- lapply(data[num_vars], function(x) ifelse(is.na(x), mean(x, na.rm = TRUE), x))
  
  # Impute missing values for categorical variables
  cat_vars <- sapply(data, is.factor)
  data[cat_vars] <- lapply(data[cat_vars], function(x) ifelse(is.na(x), "NA", x))
  
  # Convert categorical variables to factors
  data[cat_vars] <- lapply(data[cat_vars], as.factor)
  
  # Normalize numerical variables
  data[num_vars] <- lapply(data[num_vars], function(x) (x - mean(x)) / sd(x))
  
  return(data)
}

# function that removes columns with only one unqie value 
remove_unique <- function(data) {
  data <- data[, sapply(data, function(x) length(unique(x))) > 1]
  return(data)
}

# %%
install.packages("leaps")
library(leaps)
# Out:
# The downloaded binary packages are in
# 	/var/folders/j2/83k2pfk133n_vkpjy9xj72c00000gn/T//RtmpecUnCq/downloaded_packages

# %%
library(leaps)
path <- "./AmesHousing.csv"
data <- read.csv(path)
data_clean = preprocess(data)
data_clean = remove_unique(data_clean)
data_clean <- na.omit(data_clean)

# %% [markdown]
# ## Finding best features

# %%
features_fwd <- regsubsets(SalePrice ~ ., data = data_clean, nvmax=20, method="forward")
features_bwd <- regsubsets(SalePrice ~ ., data = data_clean, nvmax=20, method="backward")
features_fwd_sum = summary(features_fwd)
features_bwd_sum = summary(features_bwd)
# Out:
# Warning message in leaps.setup(x, y, wt = wt, nbest = nbest, nvmax = nvmax, force.in = force.in, :
# "7  linear dependencies found"
# Reordering variables and trying again:
# Warning message in leaps.setup(x, y, wt = wt, nbest = nbest, nvmax = nvmax, force.in = force.in, :
# "7  linear dependencies found"
# Reordering variables and trying again:

# %%
bic_min <- which.min(features_fwd_sum$bic)

# %%
plot(features_bwd_sum$bic, xlab = "Liczba zmiennych", ylab = "BIC", col = "green",
     type = "b", pch = 20)
points(bic_min, features_bwd_sum$bic[bic_min], col = "red", pch = 9)
# Out:
# plot without title

# %%
plot(features_fwd_sum$bic, xlab = "Liczba zmiennych", ylab = "BIC", col = "green",
     type = "b", pch = 20)
points(bic_min, features_fwd_sum$bic[bic_min], col = "red", pch = 9)
# Out:
# plot without title

# %% [markdown]
# ## Cross validation

# %%
predict.regsubsets <- function(object, newdata, id, ...) {
  model_formula <- as.formula(object$formula)
  mat <- model.matrix(model_formula, newdata)
  coefs <- coef(object, id = id)
  mat[, names(coefs)] %*% coefs
}

prediction_error <- function(i, model, subset, data) {
  pred <- predict(model, data[subset,], id = i)
  mean((data$SalePrice[subset] - pred)^2)
}

cross_validate_regsubsets <- function(data, k, nvmax) {
  n <- nrow(data)
  folds <- sample(1:k, n, replace = TRUE)
  val_err <- NULL
  
  # For each fold
  for (i in 1:max(folds)) {
    # Split data into training and test sets
    train <- data[folds != i, ]
    test <- data[folds == i, ]
    
    # Fit model on training set
    fit <- regsubsets(SalePrice ~ ., data = data, nvmax=nvmax, method="forward")
    
    err <- sapply(1:nvmax, prediction_error, model = fit, subset = test, data=data)
    
    val_err <- rbind(val_err, err)
  }
  
  # Return mean RMSE
  return(colMeans(val_err))
}

# %%
mean_err <- cross_validate_regsubsets(data_clean, 10, 20)
# Out:
# Warning message in leaps.setup(x, y, wt = wt, nbest = nbest, nvmax = nvmax, force.in = force.in, :
# "7  linear dependencies found"
# Reordering variables and trying again:
# Error in xj[i]: invalid subscript type 'list'
# Traceback:
#
# 1. cross_validate_regsubsets(data_clean, 10, 20)
# 2. sapply(1:nvmax, prediction_error, model = fit, subset = test,
#  .     data = data)   # at line 27 of file <text>
# 3. lapply(X = X, FUN = FUN, ...)
# 4. FUN(X[[i]], ...)
# 5. predict(model, data[subset, ], id = i)   # at line 9 of file <text>
# 6. predict.regsubsets(model, data[subset, ], id = i)
# 7. model.matrix(model_formula, newdata)   # at line 3 of file <text>
# 8. model.matrix.default(model_formula, newdata)
# 9. terms(object, data = data)
# 10. terms.formula(object, data = data)
# 11. data[subset, ]
# 12. `[.data.frame`(data, subset, )
